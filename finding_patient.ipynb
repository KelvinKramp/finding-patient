# %%
# Install pip packages in the current Jupyter kernel 
# https://jakevdp.github.io/blog/2017/12/05/installing-python-packages-from-jupyter/
import sys
# !{sys.executable} -m pip install pandas
# !{sys.executable} -m pip install fuzzywuzzy
# Out:
# ...
# WARNING: You are using pip version 21.0; however, version 21.0.1 is available.
# You should consider upgrading via the '/Users/mackliniek/anaconda3/bin/python -m pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 21.0; however, version 21.0.1 is available.
# You should consider upgrading via the '/Users/mackliniek/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
import csv
from fuzzywuzzy import fuzz
import pandas as pd
patient_database = pd.read_csv("https://medicalprogress.dev/patient_data/patient_names.csv")
# Out:
# /Users/mackliniek/anaconda3/lib/python3.8/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
patient_database
# Out:
#                      Name   Birthdate  \
# 0            Mr. D. Smith  05/10/1932
# 1          Ms. O. Johnson  30/03/1933
# 2       Mr. K.O. Williams  02/11/1933
# 3            Ms. Q. Brown  09/08/1939
# 4          Mr. D.W. Chang  19/08/1959
# 5          Mr. U.K. Jones  06/04/1961
# 6         Mr. O.P. Garcia  01/07/1966
# 7     Ms. A. Miller-Dalen  18/10/1968
# 8            Ms. E. Davis  23/09/1969
# 9             Ms. Q. Wang  11/02/1974
# 10           Ms. R. Zoeng  09/01/1980
# 11     Ms. O. Afonso-Kilo  08/09/1989
# 12  Ms. S. Rodrigez-Stylo  14/07/1998
# 13    Ms. W. Martim-Burgt  21/03/2000
# 14   Ms. A. Tomás-Adilson  17/04/2000
# 15          Ms. E. Duarte  21/11/2012
#
#                                               Address
# 0                     28 Wood Avenue, Hockley,SS5 5NU
# 1             Ty-Gwyn, Harlow Common, Harlow,CM17 9NF
# 2              21 Lagham Road, South Godstone,RH9 8HE
# 3            86 Bankside Drive, Thames Ditton,KT7 0AH
# ...

# %%
# Get input from user
name = input("Provide name: \n")
birthdate = input("Provide birthdate in format dd/mm/yyyy: \n")

# Search patient birthdate in database
for index, row in patient_database.iterrows():
        if row[1] == birthdate:
            name_patient_database = row[0]
        
# Check if patient birthdate was found
if name_patient_database != "":
    print("First name in patient database that corresponds with input birthdate =", name_patient_database)
else:
    print("Patient not found based on birthdate", birthdate)
    
# Do fuzzywuzzy comparison
Str1 = name
Str2 = name_patient_database
partial_ratio = fuzz.partial_ratio(Str1.lower(), Str2.lower())
if partial_ratio > 80:
    print("During search based on birthdate a name match was found...")
    print("Partial string ratio =", partial_ratio)
    print("Was", name_patient_database,"with birthdate", birthdate, "the patient that you were looking for?")
else:
    print("Patient not found with birthdate", birthdate, "and name", name)
# Out:
# Provide name:
# Brown
# Provide birthdate in format dd/mm/yyyy:
# 09/08/1939
# First name in patient database that corresponds with input birthdate = Ms. Q. Brown
# During search based on birthdate a name match was found...
# Partial string ratio = 100
# Was Ms. Q. Brown with birthdate 09/08/1939 the patient that you were looking for?
